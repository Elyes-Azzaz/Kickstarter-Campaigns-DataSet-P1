# %%
import pandas as pd

df1 = pd.read_csv('Kickstarter001.csv')

df1
# Out:
#       backers_count                                              blurb  \
# 0               230  I know how difficult it is to gain any experie...
# 1                34  Password based file encryption for Windows bas...
# 2               226  YaCyPi will be a turnkey solution for the Rasp...
# 3               655  An app for Mac or PC that gives you full, dire...
# 4                24  Software GPS tracker application for Apple mob...
# ...             ...                                                ...
# 3689              3  A unique tapestry of burlesque vignettes that ...
# 3690              1  Mass produce our musical A Christmas Caroline ...
# 3691              1      Eine Produktion der Jungen Akademie Stuttgart
# 3692             11  Providing opportunity for young people aged 11...
# 3693             36  A song cycle for aging millennials who expecte...
#
#                                                category  \
# 0     {"id":51,"name":"Software","analytics_name":"S...
# ...

# %%
df2= pd.read_csv('Kickstarter002.csv')
df2
# Out:
#       backers_count                                              blurb  \
# 0                56  An afrofuturism envisioning of a post-apocalyp...
# 1                 2  A dire musical ... using Gypsy swing about ris...
# 2                 3           A new music and dance musical experience
# 3                 2  A 'Proof of Concept' production of a new stage...
# 4                80  Help us take our new musical to NYMF this Summ...
# ...             ...                                                ...
# 3681              4  A website dedicated to investors of any level-...
# 3682              2  Gamified e-learning platform for cybersecurity...
# 3683              2  Una plataforma web donde encontraras animalito...
# 3684              4  日本のものづくり技術を世界に伝えるWebメディア 「DIAgate」を作るために、フィリピン...
# 3685             19  A website to facilitate the relationship betwe...
#
#                                                category  \
# 0     {"id":284,"name":"Musical","analytics_name":"M...
# ...

# %%
df3= pd.read_csv('Kickstarter003.csv')
df
# Out:
#       backers_count                                              blurb  \
# 0               230  I know how difficult it is to gain any experie...
# 1                34  Password based file encryption for Windows bas...
# 2               226  YaCyPi will be a turnkey solution for the Rasp...
# 3               655  An app for Mac or PC that gives you full, dire...
# 4                24  Software GPS tracker application for Apple mob...
# ...             ...                                                ...
# 3689              3  A unique tapestry of burlesque vignettes that ...
# 3690              1  Mass produce our musical A Christmas Caroline ...
# 3691              1      Eine Produktion der Jungen Akademie Stuttgart
# 3692             11  Providing opportunity for young people aged 11...
# 3693             36  A song cycle for aging millennials who expecte...
#
#                                                category  \
# 0     {"id":51,"name":"Software","analytics_name":"S...
# ...

# %%
df4= pd.read_csv('Kickstarter004.csv')
df4
# Out:
#       backers_count                                              blurb  \
# 0               140  Discreet safety device connects you to a dedic...
# 1                55  True Wireless, HD Audio, Ultimate Comfort, Ant...
# 2                 6  Ristola watches made in La Chaux de-Fonds, Swi...
# 3               104  Deal with the cold like a boss with battery-po...
# 4                24  Lock Your Dog is a theft-proof leash\u000b for...
# ...             ...                                                ...
# 3634              4  A day full of tango music and dance along with...
# 3635             29            The summer west coast tour of the year!
# 3636             58  A vinyl album and promotional campaign featuri...
# 3637              1  An emotional journey between piano music and p...
# 3638             48  Support the groundbreaking album featuring the...
#
#                                                category  \
# 0     {"id":341,"name":"Wearables","analytics_name":...
# ...

# %%
df5= pd.read_csv('Kickstarter005.csv')
df5
# Out:
#       backers_count                                              blurb  \
# 0               586  A book to help pass on the stories and hymns o...
# 1                31                           Financement du nouvel EP
# 2                34  Help me finance the production of my new album...
# 3                 0  Help me to promote positive trap; and potentia...
# 4                14  The debut album from the phenomenal 11-piece B...
# ...             ...                                                ...
# 1319             35  Jackie Straw is creating a psychedelic country...
# 1320             20  A Western US tour to support the release of ou...
# 1321            118  An energetic Sam Ness full-band album of crowd...
# 1322             34  An album for use during TTRPGs. From town musi...
# 1323             23    Nicholas Mudd is recording a new EP this winter
#
#                                                category  \
# 0     {"id":318,"name":"Faith","analytics_name":"Fai...
# ...

# %%
df_DataSet= pd.read_csv('Kickstarter Campaigns DataSet.csv')
df_DataSet
# Out:
#         Unnamed: 0          id  \
# 0                0  1714728788
# 1                1  1639965256
# 2                2  1582062943
# 3                3  1888984372
# 4                4  1409770586
# ...            ...         ...
# 217240      217248  1438234172
# 217241      217249   906168648
# 217242      217250   708119891
# 217243      217251   239852131
# 217244      217252  1126079486
#
#                                                      name currency  \
# 0           Urban Farm Kits: Our Solution to City Farming      CAD
# 1                    Reflections on the LHC Safety Report      USD
# 2                             Ultra-Custom Chocolate Bars      USD
# 3                           GlassWeb: Internet Monitoring      USD
# 4       Dreaming of Streaming - 96.9 FM KMRD-LP Madrid...      USD
# ...                                                   ...      ...
# 217240                          Adventures of a Lost Poet      USD
# ...
